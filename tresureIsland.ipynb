# %%
print('''*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/[TomekK]
*******************************************************************************
      ''')
print('Welcome to the Treasure Island Game')
print("Your Mission is to find the treasure")
print("You're at a Cross Road. Where do you want to go?")
while True:
    try:
        choice1 = input("\tType left or right\n")
        choice1 = choice1.lower()
        if choice1 == 'left':
            print("You've come to a lake. There is an Island in middle of the lake")
            choice2 = input("\tType wait to wait for a boat. \n\tType swim to try to swim: \n")
            choice2 = choice2.lower()
            if choice2 =='wait':
                print("You arrive at the island unharmed. There is a house with 3 doors\n")
                choice3 = input("\tOne Red, One Blue, One Green. Which door do you choose?\n")
                choice3 = choice3.lower()
                if choice3 == 'red':
                    print("Room is on Fire, You Die. Game Over")
                    break
                elif choice3 == 'blue':
                    print("You Found The TREASURE!! CONGRATULATIONS YOU WIN")
                    break
                elif choice3 == 'green':
                    print("Room full of snakes, you die. Game Over")
                    break
                else:
                    print("Either choose red, blue or green")
            elif choice2 == 'swim':
                print("You are attacked by angry crocodiles, You die. Game Over")
                break
            else:
                print("Choose to either swim or wait")
            break
        elif choice1 == 'right':
            print("You Fell into the Ditch! Game Over")
            break
        else:
            print("Choose left or right only")
    except ValueError:
        print("Only String values are excepted - either 'left' or 'right' " )
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
